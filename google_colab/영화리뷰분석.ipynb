# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 영화 데이터 수집

# %% [markdown]
# ### 유다빈 데이터

# %%
df_path = '/content/drive/My Drive/빅데이터전문가양성과정/Python/lab_ml/Project/data/movie_df.csv'
movie_df = pd.read_csv(df_path)
movie_df
# Out:
#        score                                             review  label
# 0         10                             아이보다 어른이 보면 더 좋을 영화입니다      1
# 1         10              애들영화인줄 알고 자식 손잡고 영화보러간 아빠가 울면서 나오는 영화      1
# 2         10         ㅠㅠ 혼영하며 울었습니다일상에 찌들린 직장인 마음 울리는 따뜻한 영화네요..      1
# 3         10   “What day is it?”“It’s today.”“My favorite day!”      1
# 4         10                                  아무것도 안할 때 가장 행복해요      1
# ...      ...                                                ...    ...
# 37044      1  원작은 다른 세상에 온것 같은 이질감이 컸는데 이 영화는 그냥 한국에서 강동원이 코...      0
# 37045      1                                  최근 다른영화들 공부좀 하시지~      0
# 37046      1                               이걸 내가 아침부터 봤다는개 한심하다      0
# 37047      1  이런 리얼 이후로 역대급  수렉 영화ㅎㅎ무료로 풀리면 보시길. 시간낭비. 우리의 시...      0
# 37048      2               제목이 왜 인랑인지 알겠어요. 영화보다 주위에 사람들이 죄다 인낭      0
#
# [37049 rows x 3 columns]

# %% [markdown]
# ### 김정욱님 데이터

# %%
df1_path = '/content/drive/My Drive/빅데이터전문가양성과정/Python/lab_ml/Project/data/df1.csv'
movie_df1 = pd.read_csv(df1_path)
movie_df1 = movie_df1.drop(labels='Unnamed: 0', axis=1)
movie_df1
# Out:
#        score                                             review  label
# 0         10       어린 승이 연기한 배우 너무 귀엽더라 ㅎㅎ 가족들과 보기에 딱 좋은 힐링무비~~      1
# 1          9  담보 역할 맡은 소이님과 성동일님 연기 너무 쎄게 하셔서들 혼자 가서 질질 짰네요ㅠ...      1
# 2         10  코로나 시대에 힐링이 필요했다,,, 사랑과 책임감으로 연결되는 세 사람. 추석에 힐...      1
# 3         10                 오랜만에 가족들 같이 보기 좋은 영화네요. 담보 너무 귀엽!!      1
# 4          9           간만에 재밋게 봣어요 억즙이라면 억즙일수도 있지만 9점 줘도 안아까워요.      1
# ...      ...                                                ...    ...
# 27820      1                                    ㅋㅋ 그냥..자는사람이만터라      0
# 27821      2                                        씹노잼이므니다 씹노잼      0
# 27822      1  이렇게  쓰레기영화 처음이다      그야말로  이름좀  난 배우써서  관객을 우롱...      0
# 27823      1  제일 영화에서 중요한 획심이없네요..  도대체 영화에서 관객들에게 전달하러는 의도 ...      0
# 27824      1                                   이쯤되면 다세포소녀 vs 리얼      0
#
# [27825 rows x 3 columns]

# %% [markdown]
# ### 오유진님 데이터

# %%
df2_path = '/content/drive/My Drive/빅데이터전문가양성과정/Python/lab_ml/Project/data/movie_data_total.csv'
bad_movie_path = '/content/drive/My Drive/빅데이터전문가양성과정/Python/lab_ml/Project/data/badmovie_data_total2.csv'
bad_movie_review = pd.read_csv(bad_movie_path)
movie_df2 = pd.read_csv(df2_path)
movie_df2 = pd.concat([bad_movie_review, movie_df2])
movie_df2
# Out:
#        score                                             review  label
# 0          1                                 이제 정말 그만할 때가 아닐까요?      0
# 1          1                  보다가 영화가 너무 저질이고 더럽고 예측가능해서 중간에 나옴      0
# 2          1                                 돈 받고 보아도 아까울 시간...      0
# 3          1        시간죽이기도 아깝습니다출연진 감독님 고새하신 제작진님 이제껏중 가장 엉망임니다      0
# 4          1               이게 영화냐???후속편만들려면 전판 배우들 다모아서 햇어야지 ㅋㅋ      0
# ...      ...                                                ...    ...
# 80604      3  미개한 것들아 영화라는 컨텐츠 자체가 모두 허구야. 근데 이건 상당히 가능성 높은 ...      0
# 80605      1                           문재인 정권이후 제대로된 영화가 안나오네ㅉㅉ      0
# 80606      2                                    왜곡타령좀 그만해 조센징들아      0
# 80607      1  개돼지들아... 전라도 미화 영화, 공산당 미화 영화, 좌좀 미화 영화 이런 건 왜...      0
# 80608      1                     한글은 결국 불교를 배척하는 나라의 스님이 만든건가요?      0
#
# [92865 rows x 3 columns]

# %% [markdown]
# ### 정현택님 데이터

# %%
df3_path = '/content/drive/My Drive/빅데이터전문가양성과정/Python/lab_ml/Project/data/movie_df3.csv'
movie_df3 = pd.read_csv(df3_path)
movie_df3
# Out:
#        score                                             review  label
# 0         10  붐 ! 바 ! 스 ! 틱 ! 붐붐붐 !!!!나 댄스학원 등록하러 감. 본 사람은 알...      1
# 1         10  강동원 역대 필모 중 가장 빛나는 캐릭터가 될 듯. 황정민이 물흐르듯 자연스러운 연...      1
# 2          9  강동원 춤 추는 장면 단연 빵터지는 장면 !!  생각 보다 뻔뻔하게 잘추고 표정이 ...      1
# 3         10                           강동원의 능청맞은 연기는 정말 대박이다!!!      1
# 4          9  황정민의 연기는 끝내줍니다.강동원의 연기도 말할것도없지요.스토리는 음 그냥 유쾌하게...      1
# ...      ...                                                ...    ...
# 24691      1  감독이 성격 파탄자가 아닐까 싶다 영화 내내 쌍욕에 폭력에 피범벅에 으이구 이런 식...      0
# 24692      1  다큐건 아니건 설사 다큐라도 잘만들어진 다큐가 있고 개10망작이 있는데 이건 , 개...      0
# 24693      2                            흠… 자한당찌끄러기들이 여기와서 도배를하네      0
# 24694      2  안동출신성남시장 ..경원대학교..국제카바레 ..인권..은실장..민주연합 . .전부다...      0
# 24695      1  이거 쥐명박 얘기인데 대체 무슨 논리로 이 도지사를 끌여들이는거지?ㅋㅋㅋㅋ 유튜브 ...      0
#
# [24696 rows x 3 columns]

# %% [markdown]
# ### 이재훈님 데이터

# %% [markdown]
# # 데이터 합치기

# %%
movie_review = pd.concat([movie_df,movie_df1,movie_df2, movie_df3])
movie_review
# Out:
#        score                                             review  label
# 0         10                             아이보다 어른이 보면 더 좋을 영화입니다      1
# 1         10              애들영화인줄 알고 자식 손잡고 영화보러간 아빠가 울면서 나오는 영화      1
# 2         10         ㅠㅠ 혼영하며 울었습니다일상에 찌들린 직장인 마음 울리는 따뜻한 영화네요..      1
# 3         10   “What day is it?”“It’s today.”“My favorite day!”      1
# 4         10                                  아무것도 안할 때 가장 행복해요      1
# ...      ...                                                ...    ...
# 24691      1  감독이 성격 파탄자가 아닐까 싶다 영화 내내 쌍욕에 폭력에 피범벅에 으이구 이런 식...      0
# 24692      1  다큐건 아니건 설사 다큐라도 잘만들어진 다큐가 있고 개10망작이 있는데 이건 , 개...      0
# 24693      2                            흠… 자한당찌끄러기들이 여기와서 도배를하네      0
# 24694      2  안동출신성남시장 ..경원대학교..국제카바레 ..인권..은실장..민주연합 . .전부다...      0
# 24695      1  이거 쥐명박 얘기인데 대체 무슨 논리로 이 도지사를 끌여들이는거지?ㅋㅋㅋㅋ 유튜브 ...      0
#
# [182435 rows x 3 columns]

# %% [markdown]
# ## 결측치 제거

# %%
movie_review = movie_review.dropna(axis=0)
movie_review
# Out:
#        score                                             review  label
# 0         10                             아이보다 어른이 보면 더 좋을 영화입니다      1
# 1         10              애들영화인줄 알고 자식 손잡고 영화보러간 아빠가 울면서 나오는 영화      1
# 2         10         ㅠㅠ 혼영하며 울었습니다일상에 찌들린 직장인 마음 울리는 따뜻한 영화네요..      1
# 3         10   “What day is it?”“It’s today.”“My favorite day!”      1
# 4         10                                  아무것도 안할 때 가장 행복해요      1
# ...      ...                                                ...    ...
# 24691      1  감독이 성격 파탄자가 아닐까 싶다 영화 내내 쌍욕에 폭력에 피범벅에 으이구 이런 식...      0
# 24692      1  다큐건 아니건 설사 다큐라도 잘만들어진 다큐가 있고 개10망작이 있는데 이건 , 개...      0
# 24693      2                            흠… 자한당찌끄러기들이 여기와서 도배를하네      0
# 24694      2  안동출신성남시장 ..경원대학교..국제카바레 ..인권..은실장..민주연합 . .전부다...      0
# 24695      1  이거 쥐명박 얘기인데 대체 무슨 논리로 이 도지사를 끌여들이는거지?ㅋㅋㅋㅋ 유튜브 ...      0
#
# [181536 rows x 3 columns]

# %% [markdown]
# ## label 비율 확인
# * 총 데이터 181536개
# * 긍정 1 : 11189
# * 부정 0 : 70347

# %%
movie_review['label'].value_counts()
# Out:
# 1    111189
# 0     70347
# Name: label, dtype: int64

# %%
# 데이터저장
movie_review.to_csv('/content/drive/My Drive/빅데이터전문가양성과정/Python/lab_ml/Project/data/total_review.csv', index=False)

# %% [markdown]
# # 정규표현식(re)로 한글 데이터만 남기기 (한글,띄어쓰기 포함)
# # 공백만 있는 row는 삭제

# %%
import re
movie_review['review_refined'] = movie_review['review'].apply(lambda x: re.sub('[^가-힣\s]', '', x))
movie_review = movie_review[movie_review['review_refined'].apply(lambda x: re.sub('[^가-힣]', '', x)) != '']
movie_review = movie_review[['score', 'review', 'review_refined', 'label']]
movie_review
# Out:
#        score  ... label
# 0         10  ...     1
# 1         10  ...     1
# 2         10  ...     1
# 4         10  ...     1
# 5         10  ...     1
# ...      ...  ...   ...
# 24691      1  ...     0
# 24692      1  ...     0
# 24693      2  ...     0
# 24694      2  ...     0
# 24695      1  ...     0
#
# [179027 rows x 4 columns]

# %%
movie_data = movie_review[['review_refined', 'label']]
movie_data
# Out:
#                                           review_refined  label
# 0                                 아이보다 어른이 보면 더 좋을 영화입니다      1
# 1                  애들영화인줄 알고 자식 손잡고 영화보러간 아빠가 울면서 나오는 영화      1
# 2                  혼영하며 울었습니다일상에 찌들린 직장인 마음 울리는 따뜻한 영화네요      1
# 4                                      아무것도 안할 때 가장 행복해요      1
# 5      로빈이 길을 잃었다고 말할 때 내가 널 찾아냈다고 말하던푸의 말에 눈물이 날 뻔했다...      1
# ...                                                  ...    ...
# 24691  감독이 성격 파탄자가 아닐까 싶다 영화 내내 쌍욕에 폭력에 피범벅에 으이구 이런 식...      0
# 24692  다큐건 아니건 설사 다큐라도 잘만들어진 다큐가 있고 개망작이 있는데 이건  개연성 ...      0
# 24693                             흠 자한당찌끄러기들이 여기와서 도배를하네      0
# 24694  안동출신성남시장 경원대학교국제카바레 인권은실장민주연합  전부다 우연의일치고 허구입니...      0
# 24695  이거 쥐명박 얘기인데 대체 무슨 논리로 이 도지사를 끌여들이는거지 유튜브 안보고사냐...      0
#
# [179027 rows x 2 columns]

# %% [markdown]
# ### 비율 확인
# * 총 179027개
# * 긍정 1: 108998
# * 부정 0: 70029

# %%
movie_data['label'].value_counts()
# Out:
# 1    108998
# 0     70029
# Name: label, dtype: int64

# %% [markdown]
# # 데이터 정제하기

# %%
from sklearn.model_selection import train_test_split
train_review, test_review = train_test_split(movie_data, test_size=0.33, random_state=2)
train_review.shape, test_review.shape
# Out:
# ((119948, 2), (59079, 2))

# %%
train_review[:5]
# Out:
#                                           review_refined  label
# 17929                        기대하고 봤다가 너무 실망뮬란 애니메이션이 나았다      0
# 29611  좋은배우  좋은연기  원작이 있는걸 알지 못하고 봤는데 보면서 평점이 예상가던 영화...      0
# 14332                         존쟘이엇어요 특히 사람히어로 싹모아놓고 싸울때크      1
# 64414  인터넷에 처음 평점 남겨요정말 오랜만에 영화봤는데너무 너무 최악이에요연기 다 너무 ...      0
# 4300                                 명절에 가족과 함께 보기 딱 좋아요      1

# %% [markdown]
# ## 데이터 중복확인

# %%
train_review['review_refined'].nunique(), train_review['label'].nunique()
# Out:
# (116907, 2)

# %%
# 중복제거
train_review.drop_duplicates(subset=['review_refined'], inplace=True)
len(train_review)
# Out:
# 116907

# %% [markdown]
# ## label 값 확인

# %%
train_review['label'].value_counts().plot(kind = 'bar')

# %%
print(train_review.groupby('label').size().reset_index(name = 'count'))
# Out:
#    label  count
# 0      0  46591
# 1      1  70316

# %%
print(test_review.groupby('label').size().reset_index(name = 'count'))
# Out:
#    label  count
# 0      0  23047
# 1      1  36032

# %%
# 널값 확인
print(train_review.isnull().values.any()) #> False : null값 존재x
# Out:
# False

# %%
# 만약 있다면 삭제
# train_review = train_review.dropna(how = 'any') # Null 값이 존재하는 행 제거
# print(train_review.isnull().values.any()) # Null 값이 존재하는지 확인

# %% [markdown]
# ### 데이터 공백확인

# %%
train_review['review_refined'].replace('', np.nan, inplace=True)
print(train_review.isnull().sum())
# Out:
# review_refined    0
# label             0
# dtype: int64

# %%
# 공백있다면 삭제
# train_review = train_review.dropna(how = 'any')
# print(len(train_review))

# %% [markdown]
# ## 테스트 셋 동일하게 전처리

# %%
test_review.drop_duplicates(subset = ['review_refined'], inplace=True) # review 열에서 중복인 내용이 있다면 중복 제거
test_review['review_refined'] = test_review['review_refined'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","") # 정규 표현식 수행
test_review['review_refined'].replace('', np.nan, inplace=True) # 공백은 Null 값으로 변경
test_review = test_review.dropna(how='any') # Null 값 제거
print('전처리 후 테스트용 샘플의 개수 :',len(test_review))
# Out:
# 전처리 후 테스트용 샘플의 개수 : 57994

# %%
print(test_review.isnull().sum())
# Out:
# review_refined    0
# label             0
# dtype: int64

# %% [markdown]
# # 토큰화

# %%
import nltk

# %%
# 실행할때마다 설치해야됨...
# !pip install konlpy
# Out:
# ...
#      |████████████████████████████████| 19.4MB 45.5MB/s
# ...
#      |████████████████████████████████| 92kB 9.2MB/s
# ...
#      |████████████████████████████████| 460kB 44.9MB/s
# ...
#   Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
#   Found existing installation: tweepy 3.6.0
#     Uninstalling tweepy-3.6.0:
#       Successfully uninstalled tweepy-3.6.0
# ...

# %%
import nltk
from konlpy.tag import Okt; t = Okt()
okt = Okt()

# %% [markdown]
# ## 불용어

# %%
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도',
             '를','으로','자','에','와','한','하다']

# %% [markdown]
# ## 훈련셋 테스트 셋 토큰화 적용
# * => 오래걸림....

# %%
X_train = []
for sentence in train_review['review_refined']:
    temp_X = []
    temp_X = okt.morphs(sentence, stem=True) # 토큰화
    temp_X = [word for word in temp_X if not word in stopwords] # 불용어 제거
    X_train.append(temp_X)
X_train[:3]
# Out:
# [['기대하다', '보다', '너무', '실망', '뮬란', '애니메이션', '나다'],
#  ['좋다',
#   '배우',
#   '좋다',
#   '연기',
#   '원작',
#   '있다',
#   '알',
#   '지',
#   '못',
#   '하고',
#   '보다',
#   '보다',
#   '평점',
#   '예상',
#   '가다',
#   '영화',
#   '스타워즈',
#   '같다',
#   '갑옷',
#   '웃기다',
#   '포장',
#   '만',
#   '반듯하다',
#   '영화',
#   '경성',
#   '학교',
#   '마녀',
#   '같다',
#   '주인공',
#   '곧',
#   '헐크',
#   '인',
#   '영화'],
#  ['존쟘이엇어', '요', '특히', '사람', '히어로', '싹', '모으다', '싸우다', '때', '크다']]

# %%
X_test = []
for sentence in test_review['review_refined']:
    temp_X = []
    temp_X = okt.morphs(sentence, stem=True) # 토큰화
    temp_X = [word for word in temp_X if not word in stopwords] # 불용어 제거
    X_test.append(temp_X)
X_test[:3]
# Out:
# [['이제',
#   '마블',
#   '영화',
#   '다시다',
#   '안',
#   '보다',
#   '같다',
#   '보신',
#   '분',
#   '이면',
#   '공감',
#   '안',
#   '보다',
#   '후회',
#   '겁니다'],
#  ['어벤져스', '하나', '만으로', '기대', '되다'],
#  ['정말', '역사', '다루다', '영화', '같다', '뭐', '와는', '다르다']]

# %% [markdown]
# # 정수 인코딩

# %%
from keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

# %%
print(tokenizer.word_index)
# Out:
# {'영화': 1, '보다': 2, '을': 3, '이다': 4, '없다': 5, '너무': 6, '진짜': 7, '있다': 8, '좋다': 9, '재밌다': 10, '다': 11, '만': 12, '배우': 13, '시간': 14, '되다': 15, '같다': 16, '연기': 17, '마블': 18, '정말': 19, '로': 20, '강동원': 21, '나오다': 22, '아니다': 23, '않다': 24, '최고': 25, '만들다': 26, '아깝다': 27, '점': 28, '내': 29, '안': 30, '에서': 31, '요': 32, '보고': 33, '적': 34, '나': 35, '생각': 36, '돈': 37, '자다': 38, '말': 39, '감동': 40, '가다': 41, '것': 42, '그냥': 43, '고': 44, '재미있다': 45, '더': 46, '그': 47, '평점': 48, '게': 49, '스토리': 50, '감독': 51, '인': 52, '못': 53, '재미': 54, '역사': 55, '아이언맨': 56, '왜': 57, '사람': 58, '아': 59, '어벤져스': 60, '사랑': 61, '오다': 62, '주다': 63, '모르다': 64, '이렇다': 65, '마지막': 66, '싶다': 67, '하고': 68, '년': 69, '까지': 70, '때': 71, '수': 72, '네': 73, '내용': 74, '지루하다': 75, '들다': 76, '볼': 77, '처음': 78, '역시': 79, '만큼': 80, '거': 81, '황정민': 82, '중': 83, '힐링': 84, '아쉽다': 85, '알다': 86, '꼭': 87, '재미없다': 88, '인생': 89, '두': 90, '또': 91, '뭐': 92, '많다': 93, '최악': 94, '그렇다': 95, '하': 96, '먹다': 97, '끝': 98, '넘다': 99, '하나': 100, '지': 101, '번': 1
# ...

# %%
threshold = 3
total_cnt = len(tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 30032
# 등장 빈도가 2번 이하인 희귀 단어의 수: 17309
# 단어 집합에서 희귀 단어의 비율: 57.635189131592966
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 1.7054864856294716

# %%
# 전체 단어 개수 중 빈도수 2이하인 단어 개수는 제거.
# 0번 패딩 토큰과 1번 OOV 토큰을 고려하여 +2
vocab_size = total_cnt - rare_cnt + 2
print('단어 집합의 크기 :',vocab_size)
# Out:
# 단어 집합의 크기 : 12725

# %%
tokenizer = Tokenizer(vocab_size, oov_token = 'OOV') 
tokenizer.fit_on_texts(X_train)
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)

# %%
print(X_train[:3])
# Out:
# [[174, 3, 7, 244, 557, 1788, 115], [10, 14, 10, 18, 252, 9, 240, 102, 54, 69, 3, 3, 49, 721, 42, 2, 2697, 17, 2415, 295, 2378, 13, 1, 2, 1, 2623, 1827, 17, 422, 1741, 1660, 53, 2], [1, 33, 483, 59, 151, 2239, 1153, 572, 72, 177]]

# %% [markdown]
# ### 레이블 저장

# %%
y_train = np.array(train_review['label'])
y_test = np.array(test_review['label'])

# %% [markdown]
# # 빈 샘플 제거

# %%
drop_train = [index for index, sentence in enumerate(X_train) if len(sentence) < 1]

# %%
# 빈 샘플들을 제거
X_train = np.delete(X_train, drop_train, axis=0)
y_train = np.delete(y_train, drop_train, axis=0)
print(len(X_train))
print(len(y_train))
# Out:
# 116901
# 116901

# %% [markdown]
# # 패딩

# %%
print('리뷰의 최대 길이 :',max(len(l) for l in X_train))
print('리뷰의 평균 길이 :',sum(map(len, X_train))/len(X_train))
plt.hist([len(s) for s in X_train], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 리뷰의 최대 길이 : 57
# 리뷰의 평균 길이 : 10.520979290168604

# %%
def below_threshold_len(max_len, nested_list):
  cnt = 0
  for s in nested_list:
    if(len(s) <= max_len):
        cnt = cnt + 1
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))*100))

# %%
max_len = 30
below_threshold_len(max_len, X_train)
# Out:
# 전체 샘플 중 길이가 30 이하인 샘플의 비율: 94.3559079905219

# %% [markdown]
# pad_sequence() : 전체 훈련 데이터에서 각 샘플의 길이는 서로 다를 수 있습니다. 또는 각 문서 또는 각 문장은 단어의 수가 제각각입니다. <br>모델의 입력으로 사용하려면 모든 샘플의 길이를 동일하게 맞추어야할 때가 있습니다. 이를 자연어 처리에서는 패딩(padding) 작업이라고 하는데, 보통 숫자 0을 넣어서 길이가 다른 샘플들의 길이를 맞춰줍니다. <Br>케라스에서는 pad_sequence()를 사용합니다. pad_sequence()는 정해준 길이보다 길이가 긴 샘플은 값을 일부 자르고, 정해준 길이보다 길이가 짧은 샘플은 값을 0으로 채웁니다.

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
X_train = pad_sequences(X_train, maxlen = max_len)
X_test = pad_sequences(X_test, maxlen = max_len)

# %% [markdown]
# ## LSTM으로 네이버 영화 리뷰 감성 분류하기
# * => 오래걸림

# %%
from tensorflow.keras.layers import Embedding, Dense, LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
model = Sequential()
model.add(Embedding(vocab_size, 100))
model.add(LSTM(128))
model.add(Dense(1, activation='sigmoid'))

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(X_train, y_train, epochs=15, callbacks=[es, mc], batch_size=60, validation_split=0.2)
# Out:
# Epoch 1/15
# 1559/1559 [==============================] - ETA: 0s - loss: 0.2355 - acc: 0.9033
# Epoch 00001: val_acc improved from -inf to 0.92186, saving model to best_model.h5
# 1559/1559 [==============================] - 129s 83ms/step - loss: 0.2355 - acc: 0.9033 - val_loss: 0.1985 - val_acc: 0.9219
# Epoch 2/15
# 1559/1559 [==============================] - ETA: 0s - loss: 0.1775 - acc: 0.9301
# Epoch 00002: val_acc improved from 0.92186 to 0.92746, saving model to best_model.h5
# 1559/1559 [==============================] - 124s 79ms/step - loss: 0.1775 - acc: 0.9301 - val_loss: 0.1862 - val_acc: 0.9275
# Epoch 3/15
# 1559/1559 [==============================] - ETA: 0s - loss: 0.1625 - acc: 0.9372
# Epoch 00003: val_acc improved from 0.92746 to 0.93127, saving model to best_model.h5
# 1559/1559 [==============================] - 123s 79ms/step - loss: 0.1625 - acc: 0.9372 - val_loss: 0.1785 - val_acc: 0.9313
# Epoch 4/15
# ...

# %%
loaded_model = load_model('best_model.h5')
print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(X_test, y_test)[1]))
# Out:
# 1813/1813 [==============================] - 22s 12ms/step - loss: 0.1672 - acc: 0.9356
#
#  테스트 정확도: 0.9356

# %%
def sentiment_predict(new_sentence):
  new_sentence = okt.morphs(new_sentence, stem=True) # 토큰화
  new_sentence = [word for word in new_sentence if not word in stopwords] # 불용어 제거
  encoded = tokenizer.texts_to_sequences([new_sentence]) # 정수 인코딩
  pad_new = pad_sequences(encoded, maxlen = max_len) # 패딩
  score = float(loaded_model.predict(pad_new)) # 예측
  if(score > 0.5):
    print("{:.2f}% 확률로 긍정 리뷰입니다.\n".format(score * 100))
  else:
    print("{:.2f}% 확률로 부정 리뷰입니다.\n".format((1 - score) * 100))

# %% [markdown]
# # 리뷰 예측하기

# %%
sentiment_predict('이 영화 개꿀잼 ㅋㅋㅋ')
# Out:
# 98.73% 확률로 긍정 리뷰입니다.

# %%
sentiment_predict('이 영화 핵노잼 ㅠㅠ')
# Out:
# 99.91% 확률로 부정 리뷰입니다.

# %%
sentiment_predict('감독 뭐하는 놈이냐?')
# Out:
# 99.08% 확률로 부정 리뷰입니다.

# %%
sentiment_predict('제발 돈주고 보지 마세요')
# Out:
# 99.42% 확률로 부정 리뷰입니다.

# %%
sentiment_predict('와 개쩐다 정말 세계관 최강자들의 영화다')
# Out:
# 96.73% 확률로 긍정 리뷰입니다.

# %%
sentiment_predict('진짜 너무 별로였던 영화였다. 솔직히 내용도 별로였고, 내용은 둘째치더라도 연출이 쓰레기 그 이하다. 배우들만 불쌍해지는 연출, 무얼 말하고 싶은지도 모르겠고, 연관성 및 개연성도 없고, 갑자기 백인은 나쁜놈으로 묘사되며, 특히 마지막에는 역겨운 연출을 참을 수없어서 몸을 부들부들 떨 수 밖에 없었다. 중학생이 망상으로 지꺼리는듯한 내용, 연출 10점 준애들은 제발 반성하길 바란다. 내돈 주고 이런 영화를 보다니..')
# Out:
# 93.12% 확률로 부정 리뷰입니다.

# %%
sentiment_predict('볼만해요 근데 웃음코드가 나랑은 안맞음 ㅋ')
# Out:
# 78.12% 확률로 부정 리뷰입니다.

# %%
sentiment_predict('평점보고 본건데 저는 개인적으로 엄청 재밋진않았어요 ㅠㅠㅠ')
# Out:
# 54.83% 확률로 긍정 리뷰입니다.

# %%
sentiment_predict('뻔한 스토리, 비현실적 진행, 과도한 오버 연출, 돈아깝다.')
# Out:
# 92.99% 확률로 부정 리뷰입니다.
